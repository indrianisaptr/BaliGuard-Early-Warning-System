# %% [markdown]
# # Notebook 01 — Load Semua Dataset & Exploratory Data Analysis
# ## Early Warning System Krisis Pariwisata Bali
#
# Notebook ini berisi:
# - Setup struktur folder
# - Install library yang dibutuhkan
# - Load semua dataset mentah
# - Preview awal setiap dataset (EDA dasar)

# %% [markdown]
# ## 1. Install Library

# %%
# !pip install pandas numpy matplotlib seaborn openpyxl xlrd scikit-learn langdetect
# !pip install transformers torch sentencepiece

# %% [markdown]
# ## 2. Setup Struktur Folder

# %%
import os

# Buat struktur folder project
folders = [
    '../data/raw',
    '../data/processed',
    '../data/final',
    '../models',
    '../src',
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)
    print(f'Created: {folder}')

print('\nStruktur folder berhasil dibuat!')
# Out:
# Created: ../data/raw
# Created: ../data/processed
# Created: ../data/final
# Created: ../models
# Created: ../src
#
# Struktur folder berhasil dibuat!

# %% [markdown]
# ## 3. Import Library

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 20)
pd.set_option('display.width', 120)

print('Library berhasil diimport')
# Out:
# Library berhasil diimport

# %% [markdown]
# ## 4. Load Dataset
# ### 4.1 Gab_Data_Wisman_Bali.xlsx (Wisatawan Mancanegara Gabungan)

# %%
wisman_gab = pd.read_excel('../data/raw/Gab_Data_Wisman_Bali.xlsx')
print('Shape:', wisman_gab.shape)
print('Columns:', wisman_gab.columns.tolist())
print()
wisman_gab.head(5)
# Out:
# Shape: (208, 2)
# Columns: ['Tanggal', 'Banyak']
#      Tanggal  Banyak
# 0 2009-01-01  174541
# 1 2009-02-01  147704
# 2 2009-03-01  168205
# 3 2009-04-01  188776
# 4 2009-05-01  190803

# %% [markdown]
# ### 4.2 Wisman Bulanan 1982-2008 (XLS BPS)

# %%
wisman_old = pd.read_excel(
    '../data/raw/banyaknya-wisatawan-mancanegara-bulanan-ke-bali.xls',
    engine='xlrd',
    header=None
)
print('Shape:', wisman_old.shape)
print()
wisman_old.head(6)
# Out:
# Shape: (38, 15)
#                                                   0        1        2        3        4        5        6        7   \
# 0  Banyaknya Wisatawan Mancanegara Bulanan ke Bal...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 1  Number of Monthly Foreign Visitor to Bali, 198...      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2                                                NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3                                      Bulan / Month   1982.0   1983.0   1984.0   1985.0   1986.0   1987.0   1988.0
# 4                               Januari  /  January   11961.0  12024.0  17062.0  14897.0  19378.0  22870.0  29251.0
# 5                              Pebruari  /  February  10278.0  11192.0  14038.0  16899.0  18738.0  21652.0  28207.0
#
#         8        9        10       11       12       13       14
# 0      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# ...

# %% [markdown]
# ### 4.2b Wisman Mancanegara Bali vs Indonesia Tahunan 1969–2025

# %%
# Kolom: Tahun | Indonesia Total | Indonesia Growth% | Bali Total | Bali Growth%

wisman_bali_indonesia_raw = pd.read_excel(
    '../data/raw/banyaknya-wisatawan-mancanegara-ke-bali-dan-indonesia.xls',
    engine='xlrd',
    header=None
)
print('Shape:', wisman_bali_indonesia_raw.shape)
print()
wisman_bali_indonesia_raw.head(8)
# Out:
# Shape: (36, 11)
#                                                   0          1            2      3            4   5      6   \
# 0  Jumlah Wisatawan Asing ke Indonesia dan Bali, ...        NaN          NaN    NaN          NaN NaN    NaN
# 1  Number of Foreign Visitor to Indonesia and Bal...        NaN          NaN    NaN          NaN NaN    NaN
# 2                                                NaN        NaN          NaN    NaN          NaN NaN    NaN
# 3                                              Tahun  Indonesia          NaN   Bali          NaN NaN  Tahun
# 4                                               Year      Total   Growth (%)  Total   Growth (%) NaN   Year
# 5                                               1969      86067            -  11278            - NaN   1998
# 6                                               1970     129319    50.253872  24340   115.818408 NaN   1999
# ...

# %% [markdown]
# ### 4.3 Wisatawan Domestik Bulanan 2004-2025

# %%
# Format wide: Bulan + kolom tahun 2004-2025, skiprows=3
# CATATAN: File punya 3 sheet (2004-2012, 2013-2021, 2022-2030), format wide BPS.
# Preview di sini hanya sheet default (sheet pertama) untuk pengecekan struktur awal.
# Parsing lengkap ketiga sheet + melt ke format panjang dilakukan di NB02.
wisnus = pd.read_excel(
    '../data/raw/wisnus_bali_2004_2025.xlsx',)
print('Shape:', wisnus.shape)
print()
wisnus.head(6)
# Out:
# Shape: (16, 10)
#      Wisatawan Domestik ke Bali 2004-2012  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  \
# 0  Sumber: Dinas Pariwisata Provinsi Bali         NaN         NaN         NaN         NaN         NaN         NaN
# 1                                     NaN         NaN         NaN         NaN         NaN         NaN         NaN
# 2                                   Bulan      2004.0      2005.0      2006.0      2007.0      2008.0      2009.0
# 3                                 Januari    167106.0    174515.0    202857.0    181266.0    225955.0    264915.0
# 4                                Pebruari    133660.0    161808.0    161413.0    144425.0    190792.0    204419.0
# 5                                   Maret    118369.0    194411.0    171795.0    161009.0    221181.0    255203.0
#
#    Unnamed: 7  Unnamed: 8  Unnamed: 9
# 0         NaN         NaN         NaN
# 1         NaN         NaN         NaN
# 2      2010.0      2011.0      2012.0
# ...

# %% [markdown]
# ### 4.4 Wisman berdasarkan Kebangsaan 2019-2024

# %%
wisman_kebangsaan = pd.read_excel(
    '../data/raw/-banyaknya-wisatawan-mancanegara-yang-datang-langsung-ke-bali-menurut-kebangsaan-2019-2024.xlsx',
    header=None
)
print('Shape:', wisman_kebangsaan.shape)
print()
wisman_kebangsaan.head(8)
# Out:
# Shape: (41, 9)
#                                                    0      1                        2       3       4     5       6  \
# 0  Banyaknya Wisatawan Mancanegara yang Datang La...    NaN                      NaN     NaN     NaN   NaN     NaN
# 1  Number of Foreign Visitors Arriving Directly b...    NaN                      NaN     NaN     NaN   NaN     NaN
# 2                                                NaN    NaN                      NaN     NaN     NaN   NaN     NaN
# 3                           Kebangsaan (Negara Asal)    NaN                      NaN    2019    2020  2021    2022
# 4                    Nationality (Country of Origin)    NaN                      NaN     NaN     NaN   NaN     NaN
# 5                                                 I.  ASEAN                      NaN  613509  100967     -  337769
# 6                                                NaN     1.      Malaysia / Malaysia  185256   31587     -   91064
# ...

# %% [markdown]
# **Catatan: dataset ini tidak dilanjutkan ke NB02.**
#
# Data wisman per kebangsaan hanya tersedia 2019–2024 (6 tahun), sedangkan dataset utama sistem ini
# mencakup 2009–2025. Jika di-join ke dataset bulanan, 10 tahun pertama (2009–2018) akan NaN seluruhnya.
# Alternatif (downscale angka tahunan ke bulanan dengan pembagian 12 merata) menghasilkan nilai artificial
# — tidak ada variasi antar bulan, sehingga tidak menambah sinyal nyata ke model.
#
# Jika data bulanan per kebangsaan tersedia di masa depan, fitur **concentration risk**
# (misalnya: HHI dominasi kebangsaan) dapat menjadi indikator early warning yang relevan.

# %% [markdown]
# ### 4.5 TPK Hotel Bintang

# %%
# Format wide: baris=kelas hotel bintang, kolom=bulan, mulai tahun 2000
tpk_bintang = pd.read_excel(
    '../data/raw/Tingkat Penghunian Kamar (TPK) Hotel Bintang.xlsx',
    header=None
)
print('Shape:', tpk_bintang.shape)
print()
tpk_bintang.head(8)
# Out:
# Shape: (10, 14)
#                     0                                                  1         2      3      4      5      6   \
# 0  Kelas Hotel Bintang                                                NaN       NaN    NaN    NaN    NaN    NaN
# 1                  NaN  Tingkat Penghunian Kamar (TPK) Hotel Bintang M...       NaN    NaN    NaN    NaN    NaN
# 2                  NaN                                               2000       NaN    NaN    NaN    NaN    NaN
# 3                  NaN                                            Januari  Februari  Maret  April    Mei   Juni
# 4            Bintang 5                                               56.5     59.34  58.49  62.19  61.07   68.6
# 5            Bintang 4                                              53.11     47.51  49.13  48.77  46.03  52.97
# 6            Bintang 3                                              44.41     43.55  39.68  48.55   41.2  50.48
# ...

# %% [markdown]
# ### 4.6 TPK Hotel Non Bintang

# %%
tpk_nonbintang = pd.read_excel(
    '../data/raw/Tingkat Penghunian Kamar (TPK).xlsx',
    header=None
)
print('Shape:', tpk_nonbintang.shape)
print()
tpk_nonbintang.head(8)
# Out:
# Shape: (14, 14)
#                0                                                  1         2      3      4      5      6      7   \
# 0  Kabupaten/Kota                                                NaN       NaN    NaN    NaN    NaN    NaN    NaN
# 1             NaN  Tingkat Penghunian Kamar (TPK) Hotel Non Binta...       NaN    NaN    NaN    NaN    NaN    NaN
# 2             NaN                                               2007       NaN    NaN    NaN    NaN    NaN    NaN
# 3             NaN                                            Januari  Februari  Maret  April    Mei   Juni   Juli
# 4   Kab. Jembrana                                                  -      17.3  19.65  19.89  21.26  20.34  17.14
# 5    Kab. Tabanan                                                  -     26.11  17.75  14.24  16.72   8.02   8.34
# 6     Kab. Badung                                                  -      43.4  44.15  40.45  40.09  46.29   44.2
# ...

# %% [markdown]
# ### 4.7 Lama Menginap Hotel Bintang & Non Bintang

# %%
lama_bintang = pd.read_excel(
    '../data/raw/Rata-Rata Lama Menginap Tamu Asing dan Domestik pada Hotel Bintang.xlsx',
    header=None
)
print('Lama Menginap Hotel Bintang - Shape:', lama_bintang.shape)
print()
lama_bintang.head(6)
# Out:
# Lama Menginap Hotel Bintang - Shape: (10, 14)
#                     0                                                  1         2      3      4    5     6     7   \
# 0  Kelas Hotel Bintang                                                NaN       NaN    NaN    NaN  NaN   NaN   NaN
# 1                  NaN  Rata-Rata Lama Menginap Tamu Asing dan Domesti...       NaN    NaN    NaN  NaN   NaN   NaN
# 2                  NaN                                               2000       NaN    NaN    NaN  NaN   NaN   NaN
# 3                  NaN                                            Januari  Februari  Maret  April  Mei  Juni  Juli
# 4            Bintang 5                                                  4       3.9    3.9    3.6  3.5   4.1   3.7
# 5            Bintang 4                                                4.1       4.5    4.4    4.2  4.5   3.7   3.8
#
#         8          9        10        11        12       13
# 0      NaN        NaN      NaN       NaN       NaN      NaN
# ...

# %%
lama_nonbintang = pd.read_excel(
    '../data/raw/Rata-Rata Lama Menginap Tamu Asing dan Domestik pada Hotel Non Bintang.xlsx',
    header=None
)
print('Lama Menginap Hotel Non Bintang - Shape:', lama_nonbintang.shape)
print()
lama_nonbintang.head(6)
# Out:
# Lama Menginap Hotel Non Bintang - Shape: (14, 14)
#                0                                                  1         2      3      4     5     6     7   \
# 0  Kabupaten/Kota                                                NaN       NaN    NaN    NaN   NaN   NaN   NaN
# 1             NaN  Rata-Rata Lama Menginap Tamu Asing dan Domesti...       NaN    NaN    NaN   NaN   NaN   NaN
# 2             NaN                                               2007       NaN    NaN    NaN   NaN   NaN   NaN
# 3             NaN                                            Januari  Februari  Maret  April   Mei  Juni  Juli
# 4   Kab. Jembrana                                                  -      1.88   1.56   1.55  1.79  1.13  1.24
# 5    Kab. Tabanan                                                  -      1.27   1.12   2.14  2.21  1.18  1.71
#
#         8          9        10        11        12       13
# 0      NaN        NaN      NaN       NaN       NaN      NaN
# ...

# %% [markdown]
# **Catatan: dataset lama menginap dilanjutkan ke NB02 sebagai fitur baru.**
#
# Berbeda dengan TPK (mengukur *berapa banyak* kamar terisi), lama menginap mengukur
# *seberapa lama* tamu tinggal — indikator kualitas kunjungan yang berbeda dimensi.
# Lama menginap yang memendek dapat menjadi leading indicator penurunan pariwisata
# bahkan sebelum angka wisman (kunjungan total) turun secara nyata.
#
# Format BPS kedua file identik dengan TPK Bintang & Non Bintang (Section 4.5 & 4.6),
# sehingga parsing di NB02 dapat menggunakan pola yang sama.
# Diproses di **NB02 Section 3.2** → disimpan ke `data/processed/lama_menginap_clean.csv`.

# %% [markdown]
# ### 4.8 Inflasi Bulanan Bali 2024

# %%
inflasi = pd.read_excel(
    '../data/raw/Data Inflasi.xlsx',
    header=None
)
print('Shape:', inflasi.shape)
print()
inflasi
# Out:
# Shape: (209, 4)
#                 0              1             2             3
# 0             NaN            NaN           NaN           NaN
# 1             NaN            NaN           NaN           NaN
# 2    Data Inflasi   Data Inflasi  Data Inflasi  Data Inflasi
# 3             NaN            NaN           NaN           NaN
# 4              No        Periode  Data Inflasi           NaN
# ..            ...            ...           ...           ...
# 204           200       Mei 2009        6.04 %           NaN
# 205           201     April 2009        7.31 %           NaN
# 206           202     Maret 2009        7.92 %           NaN
# 207           203  Februari 2009         8.6 %           NaN
# 208           204   Januari 2009        9.17 %           NaN
#
# [209 rows x 4 columns]

# %% [markdown]
# ### 4.9 Kurs USD/IDR Historical

# %%
# Format: Date | Price | Open | High | Low | Change %
usd_idr = pd.read_csv('../data/raw/USD_IDR Historical Data.csv')
print('Shape:', usd_idr.shape)
print('Columns:', usd_idr.columns.tolist())
print()
usd_idr.head(5)
# Out:
# Shape: (4205, 6)
# Columns: ['Date', 'Price', 'Open', 'High', 'Low', 'Change %']
#         Date      Price       Open       High        Low Change %
# 0  4/30/2026  17,310.00  17,350.00  17,387.50  17,307.50    0.17%
# 1  4/29/2026  17,280.00  17,277.50  17,337.50  17,267.50    0.38%
# 2  4/28/2026  17,215.00  17,212.50  17,249.00  17,202.50    0.15%
# 3  4/27/2026  17,190.00  17,210.00  17,237.50  17,187.50   -0.01%
# 4  4/24/2026  17,192.50  17,275.00  17,294.00  17,192.50   -0.54%

# %% [markdown]
# ### 4.10 Daily Forex Rates (Multi Currency)

# %%
# Format: currency | base_currency | currency_name | exchange_rate | date
forex = pd.read_csv('../data/raw/daily_forex_rates.csv')
print('Shape:', forex.shape)
print('Columns:', forex.columns.tolist())
print('Currency tersedia (sample):', forex['currency'].unique()[:20].tolist())
print()
# Filter IDR saja
idr_forex = forex[forex['currency'] == 'IDR']
print('IDR rows:', len(idr_forex))
idr_forex.head(5)
# Out:
# Shape: (481415, 5)
# Columns: ['currency', 'base_currency', 'currency_name', 'exchange_rate', 'date']
# Currency tersedia (sample): ['ZWL', 'GHS', 'HRK', 'HNL', 'HKD', 'GYD', 'GTQ', 'GNF', 'GMD', 'GIP', 'GGP', 'HUF', 'GEL', 'GBP', 'FKP', 'FJD', 'EUR', 'ETB', 'ERN', 'EGP']
#
# IDR rows: 3263
#     currency base_currency      currency_name  exchange_rate        date
# 21       IDR           EUR  Indonesian Rupiah   20550.940804  2026-05-21
# 238      IDR           EUR  Indonesian Rupiah   20515.495997  2026-05-20
# 350      IDR           EUR  Indonesian Rupiah   20634.394932  2026-05-19
# 607      IDR           EUR  Indonesian Rupiah   20550.645714  2026-05-18
# 738      IDR           EUR  Indonesian Rupiah   20458.933129  2026-05-17

# %% [markdown]
# ### 4.11 Merged All Hotels (Bali Hotel Reviews dengan Tanggal)

# %%
# Format: date, location, hotel, review, rating
# Dataset baru: 29.332 reviews dari 41 hotel Bali, 2009–2026, dengan tanggal lengkap
hotel_reviews = pd.read_excel(
    '../data/raw/merged_all_hotels.xlsx',
    engine='openpyxl'
)
hotel_reviews['date'] = pd.to_datetime(hotel_reviews['date'], errors='coerce')
hotel_reviews['rating'] = pd.to_numeric(hotel_reviews['rating'], errors='coerce')

print('Shape:', hotel_reviews.shape)
print('Columns:', hotel_reviews.columns.tolist())
print('Date range:', hotel_reviews['date'].min(), '->', hotel_reviews['date'].max())
print('Rating coverage:', hotel_reviews['rating'].notna().sum(), '/', len(hotel_reviews))
print('Hotels:', hotel_reviews['hotel'].nunique(), 'hotel unik')
print()
# Reviews per tahun
print('Reviews per tahun:')
print(hotel_reviews['date'].dt.year.value_counts().sort_index().to_string())
hotel_reviews.head(3)
# Out:
# Shape: (29332, 5)
# Columns: ['date', 'location', 'hotel', 'review', 'rating']
# Date range: 2009-05-03 23:59:59.999000 -> 2026-05-25 05:00:10.629000
# Rating coverage: 25628 / 29332
# Hotels: 41 hotel unik
#
# Reviews per tahun:
# date
# 2009       4
# 2010       3
# 2011       7
# 2012       5
# 2013      16
# 2014      40
# 2015      54
# 2016     243
# 2017     757
# 2018    1556
# 2019    1815
# 2020     687
# 2021     785
# 2022    1886
# 2023    3030
# 2024    4507
# 2025    8948
# 2026    4989
#                      date                                           location                 hotel  \
# 0 2009-05-03 23:59:59.999  Jl. Segara Ayu, Sanur, Denpasar Selatan, Kota ...  Segara Village Hotel
# 1 2009-09-01 23:59:59.999  Jl. Segara Ayu, Sanur, Denpasar Selatan, Kota ...  Segara Village Hotel
# 2 2009-10-12 23:59:59.999  Jl. Segara Ayu, Sanur, Denpasar Selatan, Kota ...  Segara Village Hotel
#
#                                               review  rating
# ...

# %% [markdown]
# ### 4.12 Dataset of Digital Reviews in Tourism

# %%
# Format: hanya satu kolom 'review' — tanpa tanggal, rating, atau lokasi
# Catatan: Dataset ini tidak memiliki tanggal, digunakan sebagai tambahan teks review saja
digital_reviews = pd.read_csv(
    '../data/raw/Dataset of Digital Reviews in Tourism - 2.csv',
    engine='python',
    on_bad_lines='skip'
)
print('Shape:', digital_reviews.shape)
print('Columns:', digital_reviews.columns.tolist())
print('Tidak ada tanggal — akan digabung sebagai supplement teks saja di NB03')
digital_reviews.head(3)
# Out:
# Shape: (56448, 1)
# Columns: ['review']
# Tidak ada tanggal — akan digabung sebagai supplement teks saja di NB03
#                                               review
# 0  An out of this world experience! Gita was an a...
# 1  What an amazing experience. Not only Orang-uta...
# 2  Good experience with the friendly staff at the...

# %% [markdown]
# ## 5. Ringkasan Semua Dataset

# %%
summary = {
    'Dataset': [
        'Gab_Data_Wisman_Bali',
        'Wisman Bulanan (lama)',
        'Wisman Bali vs Indonesia Tahunan',
        'Wisnus Bulanan',
        'Wisman per Kebangsaan',
        'TPK Hotel Bintang',
        'TPK Hotel Non Bintang',
        'Lama Menginap Bintang',
        'Lama Menginap Non Bintang',
        'Inflasi Bulanan',
        'USD/IDR Historical',
        'Daily Forex Rates',
        'Bali Hotel Review',
        'Digital Reviews Tourism'
    ],
    'Tipe': [
        'Time Series', 'Time Series', 'Time Series', 'Time Series', 'Cross Section',
        'Time Series', 'Time Series', 'Time Series', 'Time Series',
        'Time Series', 'Time Series', 'Time Series', 'NLP', 'NLP'
    ],
    'Kelompok': [
        'Tourism Indicator', 'Tourism Indicator', 'Tourism Indicator', 'Tourism Indicator', 'Tourism Indicator',
        'Tourism Indicator', 'Tourism Indicator', 'Tourism Indicator', 'Tourism Indicator',
        'Economic Indicator', 'Economic Indicator', 'Economic Indicator',
        'Sentiment Data', 'Sentiment Data'
    ]
}

summary_df = pd.DataFrame(summary)
print('=== RINGKASAN DATASET ===')
print(summary_df.to_string(index=False))
# Out:
# === RINGKASAN DATASET ===
#                          Dataset          Tipe           Kelompok
#             Gab_Data_Wisman_Bali   Time Series  Tourism Indicator
#            Wisman Bulanan (lama)   Time Series  Tourism Indicator
# Wisman Bali vs Indonesia Tahunan   Time Series  Tourism Indicator
#                   Wisnus Bulanan   Time Series  Tourism Indicator
#            Wisman per Kebangsaan Cross Section  Tourism Indicator
#                TPK Hotel Bintang   Time Series  Tourism Indicator
#            TPK Hotel Non Bintang   Time Series  Tourism Indicator
#            Lama Menginap Bintang   Time Series  Tourism Indicator
#        Lama Menginap Non Bintang   Time Series  Tourism Indicator
#                  Inflasi Bulanan   Time Series Economic Indicator
#               USD/IDR Historical   Time Series Economic Indicator
#                Daily Forex Rates   Time Series Economic Indicator
#                Bali Hotel Review           NLP     Sentiment Data
# ...

# %% [markdown]
# ## 6. Visualisasi Awal — Tren Wisman (EDA)

# %%
# Quick plot wisman gabungan
wisman_plot = wisman_gab.copy()
wisman_plot = wisman_plot.iloc[:, :2].copy()
wisman_plot.columns = ['date', 'wisman']
wisman_plot['date'] = pd.to_datetime(wisman_plot['date'])
wisman_plot = wisman_plot.sort_values('date')

plt.figure(figsize=(14, 5))
plt.plot(wisman_plot['date'], wisman_plot['wisman'], color='steelblue', linewidth=1.5)
plt.axvspan(pd.to_datetime('2020-01-01'), pd.to_datetime('2021-12-31'),
            alpha=0.2, color='red', label='Periode COVID (Krisis)')
plt.title('Tren Wisatawan Mancanegara ke Bali', fontsize=14)
plt.xlabel('Periode')
plt.ylabel('Jumlah Wisatawan')
plt.legend()
plt.tight_layout()
os.makedirs('../reports/figures', exist_ok=True)
plt.savefig('../reports/figures/eda_wisman_trend.png', dpi=150)
plt.show()
print('Plot disimpan ke ../reports/figures/eda_wisman_trend.png (bukan data/processed, karena itu bukan data tabular)')
# Out:
# Plot disimpan ke ../reports/figures/eda_wisman_trend.png (bukan data/processed, karena itu bukan data tabular)

# %% [markdown]
# ## 7. Missing Value Heatmap
# Visualisasi cepat missing values di semua dataset utama.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

check_datasets = {
    'wisman_gab'     : wisman_gab.iloc[:, :5],
    'wisnus (sample)': wisnus.iloc[:, :8] if 'wisnus' in dir() else pd.DataFrame(),
    'tpk_bintang'    : tpk_bintang if 'tpk_bintang' in dir() else pd.DataFrame(),
    'inflasi'        : inflasi if 'inflasi' in dir() else pd.DataFrame(),
    'usd_idr'        : usd_idr.head(50) if 'usd_idr' in dir() else pd.DataFrame(),
}
check_datasets = {k:v for k,v in check_datasets.items() if not v.empty}

n = len(check_datasets)
fig, axes = plt.subplots(1, n, figsize=(4*n, 4))
if n == 1: axes = [axes]

for ax, (name, df) in zip(axes, check_datasets.items()):
    sns.heatmap(df.isnull(), ax=ax, cbar=False, yticklabels=False,
                cmap=['#1e3a5f','#ef4444'])
    ax.set_title(name, fontsize=10, fontweight='bold')
    missing_pct = df.isnull().mean().mean() * 100
    ax.set_xlabel(f'Missing: {missing_pct:.1f}%', fontsize=8)

plt.suptitle('Missing Value Heatmap — Semua Dataset', fontsize=12, fontweight='bold', y=1.02)
plt.tight_layout()
plt.show()

# Summary tabel
print('=== Summary Missing Values ===')
for name, df in check_datasets.items():
    total_missing = df.isnull().sum().sum()
    total_cells   = df.shape[0] * df.shape[1]
    print(f'  {name:25s}: {total_missing:4d}/{total_cells} ({total_missing/total_cells*100:.1f}%)')
# Out:
# === Summary Missing Values ===
#   wisman_gab               :    0/416 (0.0%)
#   wisnus (sample)          :   15/128 (11.7%)
#   tpk_bintang              :   40/140 (28.6%)
#   inflasi                  :  217/836 (26.0%)
#   usd_idr                  :    0/300 (0.0%)

# %% [markdown]
# ## 8. Duplicate Timestamp Check
# Digunakan untuk time-series — duplicate timestamp merusak merge dan rolling feature.

# %%
print('=== DUPLICATE TIMESTAMP CHECK ===')
print()

# Cek dataset yang punya kolom tanggal
ts_checks = [
    ('wisman_gab'  , wisman_gab,   wisman_gab.columns[0]),
]
if 'hotel_reviews' in dir():
    ts_checks.append(('hotel_reviews', hotel_reviews, 'date'))

for name, df, col in ts_checks:
    if col in df.columns:
        dups = df[col].duplicated().sum()
        status = 'BERSIH' if dups == 0 else f'{dups} DUPLIKAT'
        print(f'  {name:30s}: {status}')
        if dups > 0:
            print(f'Duplikat di: {df[df[col].duplicated()][col].tolist()[:5]}')
    else:
        print(f'  {name:30s}: kolom {col!r} tidak ditemukan')

print()
print('Jika ada duplikat nanti akan digunakan .drop_duplicates(subset=[col], keep="last") sebelum merge')
# Out:
# === DUPLICATE TIMESTAMP CHECK ===
#
#   wisman_gab                    : BERSIH
#   hotel_reviews                 : 7340 DUPLIKAT
# Duplikat di: [Timestamp('2014-08-21 23:59:59.999000'), Timestamp('2015-06-14 23:59:59.999000'), Timestamp('2015-07-01 23:59:59.999000'), Timestamp('2015-09-21 00:00:00'), Timestamp('2016-08-18 23:59:59.999000')]
#
# Jika ada duplikat nanti akan digunakan .drop_duplicates(subset=[col], keep="last") sebelum merge

# %% [markdown]
# ## 9. Stationarity Test (ADF)
# Uji Augmented Dickey-Fuller untuk mengecek apakah data time-series stasioner.
# Karena Model LSTM/forecasting butuh data yang stasioner atau sudah di-differencing.

# %%
try:
    from statsmodels.tsa.stattools import adfuller
except ImportError:
    import subprocess
    subprocess.run(['pip','install','statsmodels','-q'])
    from statsmodels.tsa.stattools import adfuller

def adf_test(series, name):
    series_clean = series.dropna()
    if len(series_clean) < 20:
        print(f'  {name}: data terlalu sedikit ({len(series_clean)} baris)')
        return
    result   = adfuller(series_clean, autolag='AIC')
    p_val    = result[1]
    adf_stat = result[0]
    is_stat  = p_val < 0.05
    status   = 'STASIONER (p<0.05)' if is_stat else 'NON-STASIONER (p≥0.05)'
    print(f'  {name:35s}: ADF={adf_stat:7.3f}  p={p_val:.4f}  >> {status}')

print('=== ADF STATIONARITY TEST ===')
print()

# Buat series wisman dari wisman_gab
try:
    wg = wisman_gab.copy().iloc[:, :2]
    wg.columns = ['date', 'wisman']
    wg['wisman'] = pd.to_numeric(wg['wisman'], errors='coerce')
    adf_test(wg['wisman'], 'wisman (raw)')
    adf_test(wg['wisman'].pct_change(), 'wisman (growth MoM)')
    adf_test(wg['wisman'].diff(), 'wisman (1st difference)')
except Exception as e:
    print(f'  Error: {e}')

if 'usd_idr' in dir():
    try:
        usd_series = pd.to_numeric(
            usd_idr.iloc[:,1].astype(str).str.replace(',',''), errors='coerce').dropna()
        adf_test(usd_series, 'USD/IDR (raw)')
        adf_test(usd_series.pct_change(), 'USD/IDR (pct_change)')
    except Exception as e:
        print(f'  USD/IDR error: {e}')

print()
print('Non-stasioner >> lakukan differencing atau pct_change sebelum LSTM/ARIMA')
print('Random Forest & Isolation Forest: OK dengan non-stasioner')
# Out:
# === ADF STATIONARITY TEST ===
#
#   wisman (raw)                       : ADF= -2.614  p=0.0901  >> NON-STASIONER (p≥0.05)
#   Error: exog contains inf or nans
#   USD/IDR (raw)                      : ADF= -0.940  p=0.7746  >> NON-STASIONER (p≥0.05)
#   USD/IDR (pct_change)               : ADF=-25.471  p=0.0000  >> STASIONER (p<0.05)
#
# Non-stasioner >> lakukan differencing atau pct_change sebelum LSTM/ARIMA
# Random Forest & Isolation Forest: OK dengan non-stasioner
